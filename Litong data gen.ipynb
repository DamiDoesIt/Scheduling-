# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import numpy as np
import requests 
# ### downloading Beasley's data
# for i in range(1,9):
#     url = 'http://people.brunel.ac.uk/~mastjjb/jeb/orlib/files/airland{}.txt'.format(i)
#     r = requests.get(url)
#     with open('airland{}.txt'.format(i), 'wb') as f:
#         f.write(r.content)
#     f.close()
# with open('BeasleyInstances/airland1.txt') as f:
#     lines = f.readlines()
    
# f.close()


# In[16]:


def read_Beasley(instance):
    T = []
    E = []
    L = []
    g = []
    h = []
    S = []
    with open(instance) as f:
        lines = f.readlines()
        n = int(lines[0].split()[0]) ### [1] is freeze time, for dynamic case
        for line in lines[1:]:
            param = [int(float(i)) for i in line.split()]
            if len(param) == 6 and param[-1] != 99999:
                ## [0] is appearance time, we don't need it for the static case
                E.append(param[1])
                T.append(param[2])
                L.append(param[3])
                g.append(param[4])
                h.append(param[5])
            else: 
                S += param
        S = np.array(S).reshape(-1, n).tolist()
    return n, S, E, T, L, g, h
# n, S, E, T, L, g, h = read_Beasley('BeasleyInstances/airland1.txt')
# print(E, T, L)


# In[ ]:


def generate(): ## put everything into .txt
    return 0 


# In[ ]:


def read_data():
    return 0
